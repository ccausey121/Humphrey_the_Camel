# %%
def START():
    from Level1 import WORLD1GAME
    import time
    import numpy as np
    import scipy
    from IPython.display import Audio, display
############################################################    
    class Morality:
        def __init__(self): 
            self.evil = 0
        def evil_count(self):
            return (self.evil)
        def add_evil(self):
            self.evil += 1
    ELV = Morality()
############################################################    
    def intro():
        sr,data = scipy.io.wavfile.read('HTC MAIN THEME.wav')
        data = data[:,0]
        def playintro(x,sr):
            display(Audio(x,rate=sr, autoplay=True))
        playintro(data,sr)
############################################################
    def GAMEOVER():
        def over():
            sr,data = scipy.io.wavfile.read('HTC GAME OVER.wav')
            data = data[:,0]
            def playover(x,sr):
                display(Audio(x,rate=sr, autoplay=False))
            playover(data,sr)
        print("""
    
  ▄████     ▄▄▄          ███▄ ▄███▓   ▓█████           ▒█████      ██▒   █▓   ▓█████     ██▀███                         """)
        time.sleep(.5)
        print(""" ██▒ ▀█▒   ▒████▄       ▓██▒▀█▀ ██▒   ▓█   ▀          ▒██▒  ██▒   ▓██░   █▒   ▓█   ▀    ▓██ ▒ ██▒""")
        time.sleep(.5)
        print("""▒██░▄▄▄░   ▒██  ▀█▄     ▓██    ▓██░   ▒███            ▒██░  ██▒    ▓██  █▒░   ▒███      ▓██ ░▄█ ▒""")
        time.sleep(.5)
        print("""░▓█  ██▓   ░██▄▄▄▄██    ▒██    ▒██    ▒▓█  ▄          ▒██   ██░     ▒██ █░░   ▒▓█  ▄    ▒██▀▀█▄  """)
        time.sleep(.5)
        print("""░▒▓███▀▒    ▓█   ▓██▒   ▒██▒   ░██▒   ░▒████▒         ░ ████▓▒░      ▒▀█░     ░▒████▒   ░██▓ ▒██▒""")
        time.sleep(.5)
        print(""" ░▒   ▒     ▒▒   ▓▒█░   ░ ▒░   ░  ░   ░░ ▒░ ░         ░ ▒░▒░▒░       ░ ▐░     ░░ ▒░ ░   ░ ▒▓ ░▒▓░""")
        time.sleep(.5)
        print("""  ░   ░      ▒   ▒▒ ░   ░  ░      ░    ░ ░  ░           ░ ▒ ▒░       ░ ░░      ░ ░  ░     ░▒ ░ ▒░""")
        time.sleep(.5)
        print("""░ ░   ░      ░   ▒      ░      ░         ░            ░ ░ ░ ▒          ░░        ░        ░░   ░ """)
        time.sleep(.5)
        print("""      ░          ░  ░          ░         ░  ░             ░ ░           ░        ░  ░      ░     """)
        time.sleep(.5)
        print("""                                                                       ░                         """)
        time.sleep(.5)
        over()
############################################################   
    print("""
    """)
    print("""██╗  ██╗██╗   ██╗███╗   ███╗██████╗ ██╗  ██╗██████╗ ███████╗██╗   ██╗    ████████╗██╗  ██╗███████╗""")
    time.sleep(.5)
    print("""██║  ██║██║   ██║████╗ ████║██╔══██╗██║  ██║██╔══██╗██╔════╝╚██╗ ██╔╝    ╚══██╔══╝██║  ██║██╔════╝""")
    time.sleep(.5)
    print("""███████║██║   ██║██╔████╔██║██████╔╝███████║██████╔╝█████╗   ╚████╔╝        ██║   ███████║█████╗""")  
    time.sleep(.5)
    print("""██╔══██║██║   ██║██║╚██╔╝██║██╔═══╝ ██╔══██║██╔══██╗██╔══╝    ╚██╔╝         ██║   ██╔══██║██╔══╝""")  
    time.sleep(.5)
    print("""██║  ██║╚██████╔╝██║ ╚═╝ ██║██║     ██║  ██║██║  ██║███████╗   ██║          ██║   ██║  ██║███████╗""")
    time.sleep(.5)
    print("""╚═╝  ╚═╝ ╚═════╝ ╚═╝     ╚═╝╚═╝     ╚═╝  ╚═╝╚═╝  ╚═╝╚══════╝   ╚═╝          ╚═╝   ╚═╝  ╚═╝╚══════╝""")
    time.sleep(.5)
    print("""""")                                                                                               
    time.sleep(.5)
    print(""" ██████╗ █████╗ ███╗   ███╗███████╗██╗""")                                                            
    time.sleep(.5)
    print("""██╔════╝██╔══██╗████╗ ████║██╔════╝██║""")                                                            
    time.sleep(.5)
    print("""██║     ███████║██╔████╔██║█████╗  ██║""")                                                            
    time.sleep(.5)
    print("""██║     ██╔══██║██║╚██╔╝██║██╔══╝  ██║""")                                                            
    time.sleep(.5)
    print("""╚██████╗██║  ██║██║ ╚═╝ ██║███████╗███████╗""")                                                       
    time.sleep(.5)
    print(""" ╚═════╝╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝╚══════╝

    """)
############################################################
    time.sleep(2)
    intro()
    time.sleep(5)
############################################################
    def Ending():
        print("""end 1""")
    def WORLD2():

#WORLD 2: SHAIN LIBRARY
        play = input("""
Don't forget to scroll up and play the music!""")
        
        time.sleep(2)
        print("""

        Friendone: Thank you! I don't understand why these mascots have gone insane.""")
        time.sleep(3)
        print("""
        Friendone: Wait, I just remembered-""")
        time.sleep(1)
        print("""
        Friendone: Humphrey! Please save my friend in the upper level of Shain Library!""")
        time.sleep(4)
        print("""
        
Determined to get to the bottom of this,""")
        time.sleep(3)
        print("""Humphrey rushes to the library.""")
        time.sleep(2)
        print("""When Humphrey arrives,""")
        time.sleep(1)
        print("""he's approached by a child in wizard's robes.""")
        time.sleep(2)
        print("""
        Wizard: Humphrey!""")
        time.sleep(1)
        print("""
        Wizard: I has't inf'rmation yond shall beest critical to thy survival!""")
        time.sleep(4)
        print("""
        Wizard: Prithee, he'd mine own w'rds!""")
        time.sleep(3)
#This is the Fourth Choice; Matters
        choice2_1 = input("""

Shall you mind the wizard's plea ('1') or move onwards and upwards ('2')?
Choice:""")
        while choice2_1 != "1" and choice2_1 != "2":
            print("""
Humphrey is having a hard time deciding between this chaos.""")
            time.sleep(2)

            choice2_1 = input("""

Shall you mind the wizard's plea ('1') or move onwards and upwards ('2')?
Choice:""")
            
        WP = int(choice2_1)

        if WP==1:
            print("""
            
        Humprey: Pardon me, young scholar, for I must make haste.""")
            time.sleep(3)
            print("""   
        Humprey: But if critical, I will lend thee an ear.""")
            time.sleep(1)
            print("""
        Wizard: Wise decision, belov'd mascot.""")
            time.sleep(4)
            print("""
        Wizard: The oth'rs...""")
            time.sleep(2)
            print("""
        Wizard: has't succumb'd to a dark magic- an evil spelleth.""")
            time.sleep(4)
            print("""
        Wizard: The library holdeth many a secret.""")
            time.sleep(4)
            print("""
        Wizard: Yond much is true.""")
            time.sleep(3)
            print("""
        Wizard: Howev'r...""")
            time.sleep(3)
            print("""
            
Humphrey begins to worry about the time he has left.""")
            time.sleep(3)
            print("""Are his friends okay?..""")
            time.sleep(2)
            print("""
            
        Humphrey: Wizard, oh, Wizard! Forgive me please!""")
            time.sleep(3)
            print("""
        Humphrey: Must thee unravel this yarn so slowly?""")
            time.sleep(3)
            print("""
        Humphrey: Have I not previously mentioned the time-""")
            time.sleep(1)
            print("""
        Wizard: If 't be true thee wilt sweaty haste me...""")
            time.sleep(4)
            print("""
                widen thy ears furth'r and keepeth thy heart receptive.""")
            time.sleep(5)
            print("""
                Th're's a secret booketh in the library.""")
            time.sleep(.6)
            print("""
                T goeth by many a nameth.""")
            time.sleep(.5)
            print("""
                Issu'd into the wrong handeth t shalt doth harmeth.""")
            time.sleep(.4)
            print("""
                This same secret booketh hast been hath used f'r this reasoneth.""")
            time.sleep(.4)
            print("""
                The guise of a bulldog...""")
            time.sleep(.35)
            print("""
                hast mistakenly did destroy the heart of all Connecticut.""")
            time.sleep(.35)
            print("""
                Howev'r, one remaineth untouch'd.""")
            time.sleep(.3)
            print("""
                Yond v'ry soul shalt saveth us all from the apocalypse yond we witness.""")
            time.sleep(.3)
            print("""
                I shalt giveth thee a trinket yond shall s'rve thee well. """)
            time.sleep(.25)
            print("""
                Once thee moveth through the labyrinth of booketh and shelf,""")
            time.sleep(.25)
            print("""
                shalt thee battleth the beast,""")
            time.sleep(.25)
            print("""
                the stone shall becometh lighteth and bringeth valorous news.""")
            time.sleep(.25)
            print("""
                Thee shall not visage the image of death v'ry lief.""")
            time.sleep(.2)
            print("""
                T's f'retold in many a tale. """)
            time.sleep(.2)
            print("""
                Thou art such h'roic figure in this tale.""")
            time.sleep(.2)
            print("""
                Thee shalt saveth us all.""")
            time.sleep(1.5)
            print("""
        Wizard: Got all that?""")
            time.sleep(.5)

#Choice Fourth and a Half; has no effect

            choice2_1_5 = input("""
            
'Y'/'N'?
Choice:""")
            if choice2_1_5.upper()=="Y":
                print("""
        Wizard: Awesome.""")
            if choice2_1_5.upper()=="N":
                print("""
        Wizard: Great.""")
            if choice2_1_5.upper()!="N" and choice2_1_5.upper()!="Y":
                print("""
        Wizard: Okay.""")
            time.sleep(1.5)
            print("""
        Wizard: Just take this necklace and you should be fine.""")
            time.sleep(3)
            print("""
            
The Wizard hands Humphrey a necklace with a single stone attatched.""")
            time.sleep(4)
            print("""Keeping in mind what was spoken,""")
            time.sleep(1.5)
            
        if WP==2:
            print("""
            
        Humprey: Pardon me, young scholar, for I must make haste.""")
            time.sleep(3)
            print("""
            
Ignoring the Wizard's request,""")
            time.sleep(1.5)
            
        if WP==1 or WP == 2:
            print("""Humphrey makes his way to the fourth floor.""")
            time.sleep(3)
            print("""Upon reaching the floor,""")
            time.sleep(1.5)
            print("""he stumbles at a crossroads.""")

#Choice fifth; matters
            
            choice2_2 = input("""
           
Should Humphrey search the left ('1') area or the right ('2')?
Choice:""")
            while choice2_2 != "1" and choice2_2 != "2":
                print("""
Humphrey is having a hard time deciding between this chaos.""")
                time.sleep(2)

                choice2_2 = input("""

Should Humphrey search the left ('1') area or the right ('2')?? 
Choice:""")
            LR2 = int(choice2_2)

            if LR2 == 2:
                time.sleep(3)
                print("""
                
Humphrey goes to the right.""")
                time.sleep(2)
                print("""United States Coast Guard Academy's Objee the Bear obstructs his path!""")
                time.sleep(3)
                print("""
                
        Objee: A camel?""")
                time.sleep(1.5)
                print("""
                
        Objee: In Connecticut?!""")
                time.sleep(1.5)
                print("""
                
        Objee: How foolish!""")
                time.sleep(2)
                
#Choice fifth and a half; second evil check
                
                choice2_2_5 = input("""

Should Humphrey let out a rude remark ('1') or should he ignore Objee and continue to look for his friend ('2')?
Choice:""")
                while choice2_2_5 != "1" and choice2_2_5 != "2":
                    print("""
Humphrey is having a hard time deciding between this chaos.""")
                    time.sleep(2)

                    choice2_2_5 = input("""

Should Humphrey let out a rude remark ('1') or should he ignore Objee and continue to look for his friend ('2')?
Choice:""")
                EC2 = int(choice2_2_5)
                print("""
                
""")
                if EC2 == 1:
                    time.sleep(3)
                    print("""        Humphrey: Looks who's talking!""")
                    time.sleep(3)
                    print("""
                    
        Humphrey: A Bear for a coast guard academy?!""")
                    time.sleep(3)
                    print("""
                    
        Humphrey: Sooner than later you'd best step into a bear trap!""")
                    time.sleep(4)
                    print("""
                    
Objee made a move that anticipated a leap towards you.
""")
                    time.sleep(2)
                print("""However, another mascot intervenes""")
                time.sleep(2)
                print("""and starts a fight with him.""")
                ELV.add_evil()
                if EC2 == 2 or EC2 == 1:
                    time.sleep(2)
                    print("""Humphrey decides to turn back and go the other way.""")
            
                
            if LR2 == 1 or LR2 == 2:
                time.sleep(2)
                print("""This part of the floor is filled with books.""")
                time.sleep(3)
                print("""Humphrey starts to get lost within the shelves.""")
                time.sleep(2.5)
                print("""It's as complicated as some sort of maze.""")
                time.sleep(2)
                print("""
                
        ???: Help! Someone please!""")
                time.sleep(2)
                print("""
        [That must be the friend!]""")
                time.sleep(2)
                print("""
        Dan: Stay quiet while I find that spellbook!""")
                time.sleep(2)
                print("""
        [Dan..?]""")
                time.sleep(2)
                print("""
        [I have to save them!]""")
                pause = input("""
Don't forget to scroll up and pause the music before the game opens!""")
                print("To be continued. . .")
                time.sleep
                #WORLD2GAME()
                
                
                
############################################################################################
    def WORLD1():
        
#WORLD 1: TEMPEL GREEN
        
        print("""Humphrey wakes up in the middle of tempel green.""")
        time.sleep(2)
        print("""Recovering from a headache, he realizes that there is 
a loud chaos surrounding the school.""") 
        time.sleep(3)
        print("""What was going on? Why are there so many mascots on campus?""")
        time.sleep(3)
        print("""Humphrey can't seem to remember what went on before he woke up.""")
        time.sleep(3)
        print("""Maybe he can find a friend of his to help him remember.""")
        time.sleep(3)
        print("Time to look for them!")
        time.sleep(2)
        
#First choice; matters
        choice1_1  = input("""

Should you go rightwards towards the street ('1') or will you go leftwards towards Cummings ('2')?
Choice:""")
        
        while choice1_1 != "1" and choice1_1 != "2":
            print("""
Humphrey is having a hard time deciding between this chaos.""")
            time.sleep(2)

            choice1_1 = input("""

Should you go rightwards towards the street ('1') or will you go leftwards towards Cummings ('2')? 
Choice:""")
        LR1 = int(choice1_1) #The choices are int

        if LR1==1: 
            print("""
    
Humphrey makes his way towards the street.""")
            time.sleep(2)
            print("""
Hoping to come across a friend,""")
            time.sleep(1)
            print("""he forgets to look both ways. . .""")
            time.sleep(2)
            print("""He gets hit by a car.""")
            time.sleep(2)
            print("""Once again, he becomes unconscious.""")
            time.sleep(3)
            GAMEOVER()
            time.sleep(.5)

        if LR1==2:
            print("""

Humphrey makes his way towards Cummings.""")
            time.sleep(2)
            print("""
He tries not to attract attention as mascots seem to be fighting all over campus.""")
            time.sleep(3)
            print("""Why could they be fighting? He's determined to put a stop to this!""")
            time.sleep(3)
            print("""Yale's bulldog mascot, Handsome Dan, approaches Humphrey.""")
            time.sleep(3)
            print("""He seems angry. . .""")
            time.sleep(2)
            print("""
    
        Dan: Out of my way! I'm going to tear down this campus- go Bulldogs!""")
            time.sleep(4)
            print("""
    
This seems just a bit out of character for Dan.""")
            time.sleep(3)
            print("""Humphrey is not sure what to do.""")
            time.sleep(2)
            print("He needs to find a friend urgently.")
            time.sleep(2)
            
#Second choice; first evil check
            choice1_2 = input("""
            
Should Humphrey let out a rude remark ('1') or should he ignore Dan and continue to look for a friend ('2')?
Choice:""")
            while choice1_2 != "1" and choice1_2 != "2":
                print("""
Humphrey is having a hard time deciding between this chaos.""")
                time.sleep(2)

                choice1_2 = input("""

Should Humphrey let out a rude remark ('1') or should he ignore Dan and continue to look for a friend ('2')?
Choice:""")
            EC1 = int(choice1_2)
            
            if EC1==1:
                time.sleep(3)
                print("""
        
        Humphrey: That's a rude thing to say! You'll pay for your words soon enough!""")
                time.sleep(4)
                print("""
                
Dan looks at him incredilously before pushing past you to move on.""")
                ELV.add_evil()
                
            if EC1==2 or EC1==1:
                time.sleep(3)
                print("""
        
Humphrey is still surprised by his outburst.""")
                time.sleep(2)
                print("""
        
        [Maybe he's just having a bad day. . .]""")
                time.sleep(4)
                print("""
                
Humphrey moves forward,""")
                time.sleep(1)
                print("""looking around to find a friend to help him understand what is going on!""")
                time.sleep(3)
                print("""

        ???: What are you snooping around for!""")
                time.sleep(4)
                print("""

        [Is that?..]""")
                time.sleep(2)
                print("""
                
UConn's Jonathan the Husky!!""")
                time.sleep(2)
                print("""

        Jonathan: I'm talking to you, Humphrey!""")
                time.sleep(4)
                print("""

Why are all the mascots so angry?""")
                time.sleep(3)
                print("""
                
        [Wait! Behind Jonathan-]""")
                time.sleep(1.5)
                print("""        [That's my friend!]""")
                time.sleep(3)
                print("""
                
Jonathan has captured Humphrey's friend!""")
                time.sleep(2)

#Third Choice; has no effect
                choice1_3 = input("""

Should Humphrey confront Jonathan and save his friend ('1') or should he run away from his problems ('2')?
Choice:""")
                while choice1_3 != "1" and choice1_3 != "2":
                    print("""
Humphrey is having a hard time deciding between this chaos.""")
                    time.sleep(2)

                    choice1_3 = input("""

Should Humphrey confront Jonathan and save his friend ('1') or should he run away from his problems ('2')?
Choice:""")
                BC1 = int(choice1_3)

                if BC1==1:
                    print("""

Time for battle!""")
                if BC1==2:
                    print("""
                                 
"Humphrey ran away successfully. . ." """)
                    time.sleep(4)
                    print("""                       .""")
                    time.sleep(3.5)
                    print("""                . .""")
                    time.sleep(3.5)
                    print("""        . . .""")
                    time.sleep(3)
                    print(""". . .is what I would have said if-""")
                    time.sleep(2)
                    print("""he hadn't tripped and fallen!""")
                if BC1==1 or BC1==2:
                    time.sleep(3)
                    pause = input("""
Don't forget to scroll up and pause the music before the game opens!""")
                    WORLD1GAME()
                    time.sleep(3)
                    ready  = input("""Are you ready to continue?""")
                    WORLD2()
   
    WORLD1()
    #WORLD2GAME()
    #ENDING()

# %%
START()
